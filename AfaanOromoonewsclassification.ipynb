# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score
from mlxtend.plotting import plot_confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Embedding,Dense,LSTM,Dropout,GlobalAveragePooling1D,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
TRAIN="/content/drive/MyDrive/data/train.csv"
TEST="/content/drive/MyDrive/data/test.csv"

# %%
data=pd.read_csv(TRAIN,encoding= 'unicode_escape')
testdata=pd.read_csv(TEST,encoding= 'unicode_escape')
data.shape,testdata.shape
# Out:
# ((1078, 3), (310, 3))

# %%
data.head()
# Out:
#    Class Index                                              Title  \
# 0            4  Baalandoor: Liyooneel Mesiin badhaasa Taphataa...
# 1            3  'Seeqaan aangoo dabarsa, hoogganaan koo garuu ...
# 2            2  Hospitaalli fardaa Bishooftuutti baname tajaaj...
# 3            4  Shamarreen Iraan dirree kubbaa miilaa seente j...
# 4            3  Hoogganaan mormituu Raashiyaa ''suummeffame'' ...
#
#                                          Description
# 0  Taphataan sarara fuulduraa Paariis Seent Jerme...
# 1  Pireezidantiin Keeniyaa waggoota sagal darbani...
# 2  Hospitaalli fardaa Itoophiyaatti kan jalqabaat...
# 3  Deeggartuun kubbaa miilaa Iraan torbee dura ma...
# 4  Namni Puutiiniin mormuun beekaman kun akka dee...

# %%
data['Class Index'].value_counts()
# Out:
# 3    350
# 2    338
# 4    280
# 1    110
# Name: Class Index, dtype: int64

# %%
#Combining Title and Description --- >
X_train=data['Title']
y_train=data['Class Index'].apply(lambda x:x-1).values

# %%
testdata.head()
# Out:
#    Class Index                                              Title  \
# 0            1  Biyoonseen walaloo muuziqaa haaraa ibiddarra i...
# 1            1  Hoomaan simbiraa xiyyaara oyiruu boqqoolloo ke...
# 2            1  Raapparii fi taatoo beekamaan DMX ganna 50tti ...
# 3            1  ?Simbirroonni Masqalaa? yeroo hunda nu waliin ...
# 4            1  Artiist Hawwii Tazarraa: "Ani Qaammeen kan Oro...
#
#                                          Description
# 0  Weellistuun beekamtuu Ameerikaa Biyoonseen wal...
# 1  Xiyyaarri imaltootaa Raashiyaa erga girrisa si...
# 2  Raapparii fi taatoo beekamaan US, DMX ganna 50...
# 3  Simbirroonni Masqalaa ji'oota hedduuf erga bad...
# 4  Godina Shawaa Lixaa aanaa Ada'aa Bargaa naanno...

# %%
X_test=testdata['Title']
y_test=testdata['Class Index'].apply(lambda x:x-1).values

# %%
#Max Lenghth Of Sentences in training data-
maxlen=X_train.map(lambda x:len(x.split())).max()

# %%
maxlen
# Out:
# 18

# %%
vocab_size=12000
embed_size=32
#Creating and Fitting Tokenizers
tokenizer=Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(X_train.values)

#Tokenize Data
X_train=tokenizer.texts_to_sequences(X_train)
X_test=tokenizer.texts_to_sequences(X_test)


#Pad Sequences to the max length
X_train=pad_sequences(X_train,maxlen=maxlen)
X_test=pad_sequences(X_test,maxlen=maxlen)

# %%
model=Sequential()
model.add(Embedding(vocab_size,embed_size,input_length=maxlen))
model.add(Bidirectional(LSTM(256,return_sequences=True)))
model.add(Bidirectional(LSTM(128,return_sequences=True)))
model.add(GlobalAveragePooling1D())
model.add(Dense(1024))
model.add(Dropout(0.25))
model.add(Dense(512))
model.add(Dropout(0.25))
model.add(Dense(256))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Dropout(0.25))
model.add(Dense(64))
model.add(Dropout(0.25))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 18, 32)            384000
#
#  bidirectional (Bidirectiona  (None, 18, 512)          591872
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 18, 256)          656384
#  nal)
#
#  global_average_pooling1d (G  (None, 256)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,592,964
# Trainable params: 2,592,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks=[EarlyStopping(
    monitor='val_accuracy',
    min_delta=1e-4,
    patience=4,
    verbose=1
),
ModelCheckpoint(filepath='weights.h5',
                monitor='val_accuracy',
                mode='max',
                save_best_only=True,
                save_weights_only=True,
                verbose=1)]

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=256,validation_data=(X_test,y_test),epochs=25,callbacks=callbacks)
# Out:
# Epoch 1/25
# 5/5 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9258
# Epoch 1: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 5s 953ms/step - loss: 0.1680 - accuracy: 0.9258 - val_loss: 1.5305 - val_accuracy: 0.6387
# Epoch 2/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9629
# Epoch 2: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 7s 1s/step - loss: 0.0889 - accuracy: 0.9629 - val_loss: 2.3439 - val_accuracy: 0.6161
# Epoch 3/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9824
# Epoch 3: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 5s 932ms/step - loss: 0.0423 - accuracy: 0.9824 - val_loss: 2.9219 - val_accuracy: 0.5774
# Epoch 4/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9805
# Epoch 4: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 5s 941ms/step - loss: 0.0606 - accuracy: 0.9805 - val_loss: 3.0612 - val_accuracy: 0.6484
# Epoch 5/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9805
# Epoch 5: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 6s 1s/step - loss: 0.0617 - accuracy: 0.9805 - val_loss: 4.7344 - val_accuracy: 0.6323
# Epoch 6/25
# 5/5 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9722
# Epoch 6: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 5s 885ms/step - loss: 0.1142 - accuracy: 0.9722 - val_loss: 2.4811 - val_accuracy: 0.5806
# Epoch 7/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9889
# Epoch 7: val_accuracy did not improve from 0.68710
# 5/5 [==============================] - 6s 1s/step - loss: 0.0394 - accuracy: 0.9889 - val_loss: 1.5622 - val_accuracy: 0.6839
# Epoch 8/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9935
# Epoch 8: val_accuracy improved from 0.68710 to 0.69677, saving model to weights.h5
# 5/5 [==============================] - 5s 942ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 1.4462 - val_accuracy: 0.6968
# Epoch 9/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9907
# Epoch 9: val_accuracy did not improve from 0.69677
# 5/5 [==============================] - 5s 931ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 1.7524 - val_accuracy: 0.6484
# Epoch 10/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9954
# Epoch 10: val_accuracy did not improve from 0.69677
# 5/5 [==============================] - 6s 1s/step - loss: 0.0184 - accuracy: 0.9954 - val_loss: 1.7526 - val_accuracy: 0.6935
# Epoch 11/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9972
# Epoch 11: val_accuracy did not improve from 0.69677
# 5/5 [==============================] - 5s 880ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 2.1819 - val_accuracy: 0.6226
# Epoch 12/25
# 5/5 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9935
# Epoch 12: val_accuracy did not improve from 0.69677
# 5/5 [==============================] - 4s 891ms/step - loss: 0.0340 - accuracy: 0.9935 - val_loss: 2.1366 - val_accuracy: 0.6774
# Epoch 12: early stopping

# %%
model.load_weights('weights.h5')
model.save('model.hdf5')

# %%
def modelDemo(news_text):

  #News Labels
  labels = ['entertainment', 'health', 'politics', 'sports']

  test_seq = pad_sequences(tokenizer.texts_to_sequences(news_text), maxlen=maxlen)

  test_preds = [labels[np.argmax(i)] for i in model.predict(test_seq)]

  for news, label in zip(news_text, test_preds):
      # print('{} - {}'.format(news, label))
      print('{} - {}'.format(colored(news, 'green'), colored(label, 'red')))

# %%
from termcolor import colored

# %%
modelDemo(["Itoophiyaatti callaqeen geengoo aduutti marsee nama raaje 'Sun Halo' maali?"])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Itoophiyaatti callaqeen geengoo aduutti marsee nama raaje 'Sun Halo' maali? - health

# %%
testdata['Title'][6]
# Out:
# "Holqa 'Mana Waaqaa': Baaleetti holqi guddaan karra 47 qabu argame"

# %%
modelDemo(['Holqa Mana Waaqaa: Baaleetti holqi guddaan karra 47 qabu argame'])
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Holqa Mana Waaqaa: Baaleetti holqi guddaan karra 47 qabu argame - entertainment

# %%
modelDemo(['Waraana Tigiraay: Magaalaa Dabre Taaboritti haleellaa meeshaa guddaan gaggeeffameen miseensa maatii tokkoo keessaa shan ajjeefaman'])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Waraana Tigiraay: Magaalaa Dabre Taaboritti haleellaa meeshaa guddaan gaggeeffameen miseensa maatii tokkoo keessaa shan ajjeefaman - politics

# %%
modelDemo(['US meeshaa ammayyaa haleellaa qilleensarraa ittisu Yukireeniif erguuf'])
# Out:
# 1/1 [==============================] - 0s 37ms/step
# US meeshaa ammayyaa haleellaa qilleensarraa ittisu Yukireeniif erguuf - politics

# %%
modelDemo(['Liivarpuul peenaalitiin 5-4 Cheelsii injifatee Suppar Kaappii fudhate'])
# Out:
# 1/1 [==============================] - 0s 64ms/step
# Liivarpuul peenaalitiin 5-4 Cheelsii injifatee Suppar Kaappii fudhate - sports

# %%
preds = [np.argmax(i) for i in model.predict(X_test)]
# Out:
# 10/10 [==============================] - 1s 67ms/step

# %%
print("Recall of the model is {:.2f}".format(recall_score(y_test, preds, average='micro')))
print("Precision of the model is {:.2f}".format(precision_score(y_test, preds, average='micro')))
print("Accuracy of the model is {:.2f}".format(accuracy_score(y_test, preds)))
# Out:
# Recall of the model is 0.70
# Precision of the model is 0.70
# Accuracy of the model is 0.70
